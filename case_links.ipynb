# %%
import pandas as pd

data_path = 'data'
alire_pkg = '/alire/alire_packages_05-06-2022.csv'
alire_dep = '/alire/alire_dependencies_05-06-2022.csv'
cargo_pkg = '/cargo/cargo_packages_05-06-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_05-06-2022.csv'
chromebrew_pkg = '/chromebrew/chromebrew_packages_05-06-2022.csv'
chromebrew_dep = '/chromebrew/chromebrew_dependencies_05-06-2022.csv'
clojars_pkg = '/clojars/clojars_packages_05-06-2022.csv'
clojars_dep = '/clojars/clojars_dependencies_05-06-2022.csv'
conan_pkg = '/conan/conan_packages_005-06-2022.csv'
conan_dep = '/conan/conan_dependencies_05-06-2022.csv'
freebsd11_pkg = '/ports/freebsd11/freebsd11_packages_05-06-2022.csv'
freebsd11_dep = '/ports/freebsd11/freebsd11_dependencies_05-06-2022.csv'
fpm_pkg = '/fpm/fpm_packages_05-06-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_05-06-2022.csv'
homebrew_pkg = '/homebrew/homebrew_packages_05-06-2022.csv'
homebrew_dep = '/homebrew/homebrew_dependencies_05-06-2022.csv'
netbsd9_pkg = '/ports/netbsd9/netbsd9_packages_04-28-2022.csv'
netbsd9_dep = '/ports/netbsd9/netbsd9_dependencies_04-28-2022.csv'
nimble_pkg = '/nimble/nimble_packages_03-18-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_03-18-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_05-10-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_05-10-2022.csv'
rubygems_pkg = '/rubygems/rubygems_packages_05-06-2022.csv'
rubygems_dep = '/rubygems/rubygems_dependencies_05-06-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_05-06-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_05-06-2022.csv'
lua_pkg = '/luarocks/luarocks_packages_05-06-2022.csv'
lua_dep = '/luarocks/luarocks_dependencies_05-06-2022.csv'
npm_pkg = '/npm/npm_packages_05-06-2022.csv'
npm_dep = '/npm/npm_dependencies_05-06-2022.csv'



# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    file_path = os.path.abspath(data_path + path)
    return pd.read_csv(file_path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.target_name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['target_name'].isin(x.symmetric_difference(y))]

## Removed code for packages with no findings
## NetBSD9, FreeBSD11, Conan, Cargo, VCPKG

# %%
# difference(_df(clojars_dep),_df(clojars_pkg))
df = difference(_df(alire_dep),_df(alire_pkg))
df.to_csv("alire_output.csv")
len(df.index)
# Out:
# 35

# %%
df = difference(_df(clojars_dep),_df(clojars_pkg))
df.to_csv("clojars_output.csv")
df
# Out:
#         pkg_idx  source_idx  target_idx                  source_name  \
# 0             0           0         NaN    _7696122/clojure-poloniex
# 4             0           0         NaN    _7696122/clojure-poloniex
# 6             0           0         NaN    _7696122/clojure-poloniex
# 7             0           0         NaN    _7696122/clojure-poloniex
# 8             1           1         NaN  aaron-santos/clj-tiny-astar
# ...         ...         ...         ...                          ...
# 963690    28955      168121         NaN                      zyzanie
# 963693    28955      168122         NaN                      zyzanie
# 963695    28955      168123         NaN                      zyzanie
# 963697    28955      168124         NaN                      zyzanie
# 963700    28955      168125         NaN                      zyzanie
#
#                           target_name  source_version target_version   kind
# ...

# %%
df = difference(_df(cargo_dep),_df(cargo_pkg))
df.to_csv("cargo_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, optional, target]
# Index: []

# %%
df = difference(_df(chromebrew_dep),_df(chromebrew_pkg))
df.to_csv("chromebrew_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx        source_name    target_name  \
# 30         16           0         NaN              hplip  libjpeg_turbo
# 449       177           0         NaN                  r       gfortran
# 524       199           0         NaN             ffmpeg         x86_64
# 525       199           0         NaN             ffmpeg   GenuineIntel
# 537       199           0         NaN             ffmpeg           i686
# 538       199           0         NaN             ffmpeg   GenuineIntel
# 866       309           0         NaN     buildessential            gyp
# 1149      424           0         NaN           testdisk  libjpeg_turbo
# 1527      534           0         NaN               bash           i686
# 1693      597           0         NaN  template.template              *
# 2100      757           0         NaN     musl_toolchain           i686
# 2102      757           0         NaN     musl_toolchain           i686
# ...

# %%
df = difference(_df(conan_dep),_df(conan_pkg))
df.to_csv("conan_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, revision]
# Index: []

# %%
df = difference(_df(freebsd11_dep),_df(freebsd11_pkg))
df.to_csv("freebsd11_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind]
# Index: []

# %%
df = difference(_df(fpm_dep),_df(fpm_pkg))
df.to_csv("fpm_output.csv")
df
# Out:
#     pkg_idx  source_idx  target_idx source_name    target_name source_version  \
# 2         2           3         NaN      jsonff         erloff          3.0.0
# 4         2           3         NaN      jsonff          parff          3.0.0
# 9        12          13         NaN       quaff         erloff          0.4.0
# 11       12          13         NaN       quaff          parff          0.4.0
# 13       12          13         NaN       quaff  quaff_asserts          0.4.0
#
#    target_version   kind
# 2          v2.1.0  BUILD
# 4          v3.1.4  BUILD
# 9          v2.1.0  BUILD
# 11         v3.1.0  BUILD
# 13            NaN    DEV

# %%
df = difference(_df(homebrew_dep),_df(homebrew_pkg))
df.to_csv("homebrew_output.csv")
df
# Out:
#        pkg_idx  source_idx  target_idx   source_name target_name  \
# 1707       743         743         NaN  clang-format      python
# 3776      1576        1576         NaN    fontconfig      python
# 4292      1719        1719         NaN       genders      python
# 6599      2548        2548         NaN         julia      python
# 10304     3806        3806         NaN          node      python
# 10340     3812        3812         NaN       node@16      python
# 12931     4638        4638         NaN     rethinkdb      python
#
#       source_version  target_version             kind
# 1707          14.0.2             NaN  USES_FROM_MACOS
# 3776          2.14.0             NaN            build
# 4292          1.27.3             NaN            build
# 6599           1.7.2             NaN            build
# 10304         18.0.0             NaN  USES_FROM_MACOS
# 10340        16.15.0             NaN  USES_FROM_MACOS
# 12931          2.4.2             NaN            build

# %%
df = difference(_df(netbsd9_dep),_df(netbsd9_pkg))
df.to_csv("netbsd9_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx                source_name  \
# 7551     9836        9836         NaN  meta-pkgs/bulk-test-boost
#
#                target_name  source_version  target_version   kind
# 7551  security/botan-devel             NaN             NaN  BUILD

# %%
df = difference(_df(nimble_dep),_df(nimble_pkg))
df.to_csv("nimble_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx source_name target_name source_version  \
# 0         NaN           0         NaN     libtcod         nim        1.112.0
# 2       666.0           1         NaN      netpbm         nim          0.1.0
# 3         NaN           2         NaN     xgboost         nim          0.1.3
# 4      1447.0           3         NaN   parasound         nim          1.0.0
# 5       954.0           4         NaN   nimassets         nim          0.2.3
# ...       ...         ...         ...         ...         ...            ...
# 3214    574.0        1906         NaN        jack         nim          0.1.0
# 3215   1530.0        1907         NaN     timelog         nim          1.3.0
# 3217   1006.0        1909         NaN    parseini         nim          0.2.0
# 3218   1476.0        1910         NaN     packets         nim          0.4.1
# 3221   1185.0        1911         NaN   asciitype         nim          0.1.0
#
#      target_version   kind
# ...

# %%
df = difference(_df(openbsd69_dep),_df(openbsd69_pkg))
df.to_csv("openbsd69_output.csv")
df
# Out:
#        pkg_idx  source_idx  target_idx        source_name  \
# 64          22          22         NaN   archivers/libtar
# 65          22          22         NaN   archivers/libtar
# 70          24          24         NaN  archivers/luazlib
# 71          24          24         NaN  archivers/luazlib
# 72          24          24         NaN  archivers/luazlib
# ...        ...         ...         ...                ...
# 28552     7417        7417         NaN        x11/yakuake
# 28556     7417        7417         NaN        x11/yakuake
# 28558     7417        7417         NaN        x11/yakuake
# 28559     7417        7417         NaN        x11/yakuake
# 28561     7417        7417         NaN        x11/yakuake
#
#                          target_name source_version  target_version   kind
# 64               devel/autoconf/2.69            NaN             NaN  BUILD
# 65               devel/automake/1.11            NaN             NaN  BUILD
# ...

# %%
df = difference(_df(rubygems_dep),_df(rubygems_pkg))
df.to_csv("rubygems_output.csv")
df
# Out:
#          pkg_idx  source_idx  target_idx          source_name  \
# 7163         590         590         NaN          ach_builder
# 7165         590         590         NaN          ach_builder
# 11435        831         831         NaN     actionmailer_csi
# 11436        831         831         NaN     actionmailer_csi
# 11437        831         831         NaN     actionmailer_csi
# ...          ...         ...         ...                  ...
# 2423235   168551      168549         NaN        zalk_services
# 2425289   168715      168713         NaN             zencoder
# 2425291   168715      168713         NaN             zencoder
# 2426641   168742      168740         NaN  zendesk_remote_auth
# 2428185   168837      168835         NaN           zerigo_dns
#
#              target_name source_version target_version         kind
# 7163      active_support        0.0.1.1       >= 2.3.0      runtime
# 7165      active_support          0.0.2       >= 2.3.0      runtime
# ...

# %%
df = difference(_df(vcpkg_dep),_df(vcpkg_pkg))
df.to_csv("vcpkg_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, os_platform]
# Index: []

# %%
df = difference(_df(lua_dep),_df(lua_pkg))
df.to_csv("lua_output.csv")
df
# Out:
#      pkg_idx  source_idx  target_idx source_name                 target_name  \
# 0          0           0         NaN       30log                  lua >= 5.1
# 1          0           0         NaN       30log                       <=5.3
# 2          0           1         NaN       30log                  lua >= 5.1
# 3          0           1         NaN       30log                       <=5.3
# 4          0           2         NaN       30log                  lua >= 5.1
# ..       ...         ...         ...         ...                         ...
# 824     3081       12464         NaN     Xavante            'copas >= 1.1.5'
# 825     3081       12464         NaN     Xavante   'luafilesystem >= 1.4.2'
# 826     3081       12467         NaN     Xavante                 'luasocket'
# 827     3081       12467         NaN     Xavante               'copas 1.1.1'
# 828     3081       12467         NaN     Xavante   'luafilesystem 1.4.1rc1'
#
#     source_version  target_version   kind
# ...

# %%
df = difference(_df(npm_dep),_df(npm_pkg))
df.to_csv("npm_output.csv")
df
# Out:
#            pkg_idx  source_idx  target_idx           source_name  \
# 48               7          20         NaN             --hiljson
# 50               7          21         NaN             --hiljson
# 51               7          21         NaN             --hiljson
# 53               7          22         NaN             --hiljson
# 54               7          22         NaN             --hiljson
# ...            ...         ...         ...                   ...
# 382248586  1957492    25255755         NaN  zzc-react-native-cli
# 382262558  1957637    25256350         NaN       zzl-com-scripts
# 382262636  1957637    25256351         NaN       zzl-com-scripts
# 382286524  1957975    25257822         NaN               zzztest
# 382286526  1957975    25257823         NaN               zzztest
#
#                                                  target_name source_version  \
# 48                               odfvkjefjkfrjkfrjkfrkjefkej         2.2.10
# ...
