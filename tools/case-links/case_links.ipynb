# %%
import pandas as pd

data_path = '../../dasea_data'
alire_pkg = '/alire/alire_packages_05-17-2022.csv'
alire_dep = '/alire/alire_dependencies_05-17-2022.csv'
cargo_pkg = '/cargo/cargo_packages_05-17-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_05-17-2022.csv'
chromebrew_pkg = '/chromebrew/chromebrew_packages_05-17-2022.csv'
chromebrew_dep = '/chromebrew/chromebrew_dependencies_05-17-2022.csv'
clojars_pkg = '/clojars/clojars_packages_05-19-2022.csv'
clojars_dep = '/clojars/clojars_dependencies_05-19-2022.csv'
conan_pkg = '/conan/conan_packages_05-17-2022.csv'
conan_dep = '/conan/conan_dependencies_05-17-2022.csv'
freebsd11_pkg = '/ports/freebsd12/freebsd12_packages_05-17-2022.csv'
freebsd11_dep = '/ports/freebsd12/freebsd12_dependencies_05-17-2022.csv'
fpm_pkg = '/fpm/fpm_packages_05-17-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_05-17-2022.csv'
homebrew_pkg = '/homebrew/homebrew_packages_05-17-2022.csv'
homebrew_dep = '/homebrew/homebrew_dependencies_05-17-2022.csv'
netbsd9_pkg = '/ports/netbsd9/netbsd9_packages_05-17-2022.csv'
netbsd9_dep = '/ports/netbsd9/netbsd9_dependencies_05-17-2022.csv'
nimble_pkg = '/nimble/nimble_packages_05-17-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_05-17-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_05-17-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_05-17-2022.csv'
rubygems_pkg = '/rubygems/rubygems_packages_05-17-2022.csv'
rubygems_dep = '/rubygems/rubygems_dependencies_05-17-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_05-17-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_05-17-2022.csv'
lua_pkg = '/luarocks/luarocks_packages_05-17-2022.csv'
lua_dep = '/luarocks/luarocks_dependencies_05-17-2022.csv'
npm_pkg = '/npm/npm_packages_05-17-2022.csv'
npm_dep = '/npm/npm_dependencies_05-17-2022.csv'



# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    file_path = os.path.abspath(data_path + path)
    return pd.read_csv(file_path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.target_name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['target_name'].isin(x.symmetric_difference(y))]

## Removed code for packages with no findings
## NetBSD9, FreeBSD11, Conan, Cargo, VCPKG

# %%
# difference(_df(clojars_dep),_df(clojars_pkg))
df = difference(_df(alire_dep),_df(alire_pkg))
df.to_csv("out/alire_output.csv")
len(df.index)
# Out:
# 35

# %%
df = difference(_df(clojars_dep),_df(clojars_pkg))
df.to_csv("out/clojars_output.csv")
df
# Out:
#         pkg_idx  source_idx  target_idx                  source_name  \
# 0             0           0         NaN    _7696122/clojure-poloniex
# 4             0           0         NaN    _7696122/clojure-poloniex
# 6             0           0         NaN    _7696122/clojure-poloniex
# 7             0           0         NaN    _7696122/clojure-poloniex
# 8             1           1         NaN  aaron-santos/clj-tiny-astar
# ...         ...         ...         ...                          ...
# 966721    28995      168559         NaN                      zyzanie
# 966724    28995      168560         NaN                      zyzanie
# 966726    28995      168561         NaN                      zyzanie
# 966728    28995      168562         NaN                      zyzanie
# 966731    28995      168563         NaN                      zyzanie
#
#                           target_name  source_version target_version   kind
# ...

# %%
df = difference(_df(cargo_dep),_df(cargo_pkg))
df.to_csv("out/cargo_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, optional, target]
# Index: []

# %%
df = difference(_df(chromebrew_dep),_df(chromebrew_pkg))
df.to_csv("out/chromebrew_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx        source_name    target_name  \
# 30         16           0         NaN              hplip  libjpeg_turbo
# 450       177           0         NaN                  r       gfortran
# 525       199           0         NaN             ffmpeg         x86_64
# 526       199           0         NaN             ffmpeg   GenuineIntel
# 538       199           0         NaN             ffmpeg           i686
# 539       199           0         NaN             ffmpeg   GenuineIntel
# 867       309           0         NaN     buildessential            gyp
# 1154      425           0         NaN           testdisk  libjpeg_turbo
# 1163      435           0         NaN               popt         x86_64
# 1537      535           0         NaN               bash           i686
# 1703      599           0         NaN  template.template              *
# 2147      761           0         NaN     musl_toolchain           i686
# ...

# %%
df = difference(_df(conan_dep),_df(conan_pkg))
df.to_csv("out/conan_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, revision]
# Index: []

# %%
df = difference(_df(freebsd11_dep),_df(freebsd11_pkg))
df.to_csv("out/freebsd11_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind]
# Index: []

# %%
df = difference(_df(fpm_dep),_df(fpm_pkg))
df.to_csv("out/fpm_output.csv")
df
# Out:
#     pkg_idx  source_idx  target_idx source_name    target_name source_version  \
# 2         2           3         NaN      jsonff         erloff          3.0.0
# 4         2           3         NaN      jsonff          parff          3.0.0
# 9        12          13         NaN       quaff         erloff          0.4.0
# 11       12          13         NaN       quaff          parff          0.4.0
# 13       12          13         NaN       quaff  quaff_asserts          0.4.0
#
#    target_version   kind
# 2          v2.1.0  BUILD
# 4          v3.1.4  BUILD
# 9          v2.1.0  BUILD
# 11         v3.1.0  BUILD
# 13            NaN    DEV

# %%
df = difference(_df(homebrew_dep),_df(homebrew_pkg))
df.to_csv("out/homebrew_output.csv")
df
# Out:
#        pkg_idx  source_idx  target_idx   source_name target_name  \
# 1097       441         441         NaN          blis      python
# 1723       745         745         NaN  clang-format      python
# 2802      1223        1223         NaN       doxygen      python
# 3802      1580        1580         NaN    fontconfig      python
# 4328      1724        1724         NaN       genders      python
# 6653      2554        2554         NaN         julia      python
# 10402     3824        3824         NaN          node      python
# 10438     3830        3830         NaN       node@16      python
# 13051     4658        4658         NaN     rethinkdb      python
# 15310     5565        5565         NaN    uncrustify      python
#
#       source_version  target_version             kind
# 1097           0.9.0             NaN            build
# 1723          14.0.3             NaN  USES_FROM_MACOS
# 2802           1.9.4             NaN            build
# ...

# %%
df = difference(_df(netbsd9_dep),_df(netbsd9_pkg))
df.to_csv("out/netbsd9_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx                source_name  \
# 7577     9840        9840         NaN  meta-pkgs/bulk-test-boost
#
#                target_name  source_version  target_version   kind
# 7577  security/botan-devel             NaN             NaN  BUILD

# %%
df = difference(_df(nimble_dep),_df(nimble_pkg))
df.to_csv("out/nimble_output.csv")
df
# Out:
#       pkg_idx  source_idx  target_idx source_name target_name source_version  \
# 0         NaN           0         NaN     libtcod         nim        1.112.0
# 2       672.0           1         NaN      netpbm         nim          0.1.0
# 3         NaN           2         NaN     xgboost         nim          0.1.3
# 4      1457.0           3         NaN   parasound         nim          1.0.0
# 5       960.0           4         NaN   nimassets         nim          0.2.4
# ...       ...         ...         ...         ...         ...            ...
# 3342    580.0        1958         NaN        jack         nim          0.1.0
# 3343   1540.0        1959         NaN     timelog         nim          1.3.0
# 3345   1012.0        1961         NaN    parseini         nim          0.2.0
# 3346   1486.0        1962         NaN     packets         nim          0.4.1
# 3349   1195.0        1963         NaN   asciitype         nim          0.1.0
#
#      target_version   kind
# ...

# %%
df = difference(_df(openbsd69_dep),_df(openbsd69_pkg))
df.to_csv("out/openbsd69_output.csv")
df
# Out:
#        pkg_idx  source_idx  target_idx        source_name  \
# 62          22          22         NaN   archivers/libtar
# 64          22          22         NaN   archivers/libtar
# 70          24          24         NaN  archivers/luazlib
# 71          24          24         NaN  archivers/luazlib
# 72          24          24         NaN  archivers/luazlib
# ...        ...         ...         ...                ...
# 28555     7417        7417         NaN        x11/yakuake
# 28557     7417        7417         NaN        x11/yakuake
# 28558     7417        7417         NaN        x11/yakuake
# 28561     7417        7417         NaN        x11/yakuake
# 28563     7417        7417         NaN        x11/yakuake
#
#                          target_name source_version  target_version   kind
# 62               devel/automake/1.11            NaN             NaN  BUILD
# 64               devel/autoconf/2.69            NaN             NaN  BUILD
# ...

# %%
df = difference(_df(rubygems_dep),_df(rubygems_pkg))
df.to_csv("out/rubygems_output.csv")
df
# Out:
#          pkg_idx  source_idx  target_idx          source_name  \
# 7121         589        3560         NaN          ach_builder
# 7123         589        3561         NaN          ach_builder
# 11427        830        5713         NaN     actionmailer_csi
# 11428        830        5714         NaN     actionmailer_csi
# 11429        830        5714         NaN     actionmailer_csi
# ...          ...         ...         ...                  ...
# 2431255   168722     1215627         NaN        zalk_services
# 2433309   168886     1216654         NaN             zencoder
# 2433311   168886     1216655         NaN             zencoder
# 2434671   168913     1217335         NaN  zendesk_remote_auth
# 2436217   169008     1218108         NaN           zerigo_dns
#
#              target_name source_version target_version         kind
# 7121      active_support        0.0.1.1       >= 2.3.0      runtime
# 7123      active_support          0.0.2       >= 2.3.0      runtime
# ...

# %%
df = difference(_df(vcpkg_dep),_df(vcpkg_pkg))
df.to_csv("out/vcpkg_output.csv")
df
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, os_platform]
# Index: []

# %%
df = difference(_df(lua_dep),_df(lua_pkg))
df.to_csv("out/lua_output.csv")
df
# Out:
#      pkg_idx  source_idx  target_idx source_name                 target_name  \
# 0          0           0         NaN       30log                  lua >= 5.1
# 1          0           0         NaN       30log                       <=5.3
# 2          0           1         NaN       30log                  lua >= 5.1
# 3          0           1         NaN       30log                       <=5.3
# 4          0           2         NaN       30log                  lua >= 5.1
# ..       ...         ...         ...         ...                         ...
# 836     3090       12533         NaN     Xavante            'copas >= 1.1.5'
# 837     3090       12533         NaN     Xavante   'luafilesystem >= 1.4.2'
# 838     3090       12536         NaN     Xavante                 'luasocket'
# 839     3090       12536         NaN     Xavante               'copas 1.1.1'
# 840     3090       12536         NaN     Xavante   'luafilesystem 1.4.1rc1'
#
#     source_version  target_version   kind
# ...

# %%
df = difference(_df(npm_dep),_df(npm_pkg))
df.to_csv("out/npm_output.csv")
df
# Out:
#            pkg_idx  source_idx  target_idx           source_name  \
# 48               7          20         NaN             --hiljson
# 50               7          21         NaN             --hiljson
# 51               7          21         NaN             --hiljson
# 53               7          22         NaN             --hiljson
# 54               7          22         NaN             --hiljson
# ...            ...         ...         ...                   ...
# 387020405  1971524    25546301         NaN  zzc-react-native-cli
# 387034377  1971669    25546896         NaN       zzl-com-scripts
# 387034455  1971669    25546897         NaN       zzl-com-scripts
# 387058782  1972014    25548403         NaN               zzztest
# 387058784  1972014    25548404         NaN               zzztest
#
#                                                  target_name source_version  \
# 48                               odfvkjefjkfrjkfrjkfrkjefkej         2.2.10
# ...
