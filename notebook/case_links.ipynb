# %%
import pandas as pd
data_path = '../data'
conan_pkg = '/conan/conan_packages_03-18-2022.csv'
conan_dep = '/conan/conan_dependencies_03-18-2022.csv'
freebsd11_pkg = '/ports/freebsd11/freebsd11_packages_03-18-2022.csv'
freebsd11_dep = '/ports/freebsd11/freebsd11_dependencies_03-18-2022.csv'
fpm_pkg = '/fpm/fpm_packages_03-18-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_03-18-2022.csv'
alire_pkg = '/alire/alire_packages_03-18-2022.csv'
alire_dep = '/alire/alire_dependencies_03-18-2022.csv'
cargo_pkg = '/cargo/cargo_packages_03-18-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_03-18-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_03-18-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_03-18-2022.csv'
nimble_pkg = '/nimble/nimble_packages_03-18-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_03-18-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_03-18-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_03-18-2022.csv'

# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    return pd.read_csv(data_path + path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['name'].isin(x.symmetric_difference(y))]

## Use if you want to find packages that match in ecosystems by name 
def intersect(df_x, df_y):
    x = set(df_x.name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['name'].isin(x.intersection(y))]

def check_transitvity(df_a, df_b, df_c):
    # Transitive dependency when A --> B --> C (A has dependency to C)
    not_ac_df = difference(df_a, df_c)
    return not_ac_df
    
# check_transitvity(_df(vcpkg_pkg), _)

# %%
intersect(_df(vcpkg_pkg), _df_ports(openbsd69_pkg))
# Out:
#        idx      name pkgman
# 4        4       ace  VCPKG
# 12      12   alembic  VCPKG
# 25      25       aom  VCPKG
# 27      27       apr  VCPKG
# 28      28  apr-util  VCPKG
# ...    ...       ...    ...
# 1842  1842        z3  VCPKG
# 1844  1844    zeromq  VCPKG
# 1850  1850    zopfli  VCPKG
# 1852  1852      zstd  VCPKG
# 1858  1858   zziplib  VCPKG
#
# [310 rows x 3 columns]

# %%
import pandas as pd

data_path = '../data'
conan_pkg = '/conan/conan_packages_03-18-2022.csv'
conan_dep = '/conan/conan_dependencies_03-18-2022.csv'
freebsd11_pkg = '/ports/freebsd11/freebsd11_packages_03-18-2022.csv'
freebsd11_dep = '/ports/freebsd11/freebsd11_dependencies_03-18-2022.csv'
fpm_pkg = '/fpm/fpm_packages_03-18-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_03-18-2022.csv'
alire_pkg = '/alire/alire_packages_03-18-2022.csv'
alire_dep = '/alire/alire_dependencies_03-18-2022.csv'
cargo_pkg = '/cargo/cargo_packages_03-18-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_03-18-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_03-18-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_03-18-2022.csv'
nimble_pkg = '/nimble/nimble_packages_03-18-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_03-18-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_03-18-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_03-18-2022.csv'

# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    file_path = os.path.abspath(data_path + path)
    return pd.read_csv(file_path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.target_name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['target_name'].isin(x.symmetric_difference(y))]

#_df(openbsd69_pkg)
#'gnatt' in _df(vcpkg_pkg)

# %%
difference(_df(openbsd69_dep),_df(openbsd69_pkg))
# lang/lua/5.1 References to the lua language?
# x11/qt5/qttools	 https://github.com/qt/qttools  https://code.qt.io/cgit/qt/qttools.git/tree/

# devel/kf5/kdoctools https://ftp.netbsd.org/pub/pkgsrc/current/pkgsrc/devel/kdoctools/index.html NetBSD
# devel/kf5/extra-cmake-modules	https://www.freshports.org/devel/kf5-extra-cmake-modules #The Extra CMake Modules package, or ECM, adds to the modules provided by CMake,
# Out:
#        pkg_idx  source_idx  target_idx        source_name  \
# 61          22          22         NaN   archivers/libtar
# 62          22          22         NaN   archivers/libtar
# 70          24          24         NaN  archivers/luazlib
# 71          24          24         NaN  archivers/luazlib
# 72          24          24         NaN  archivers/luazlib
# ...        ...         ...         ...                ...
# 28554     7417        7417         NaN        x11/yakuake
# 28555     7417        7417         NaN        x11/yakuake
# 28558     7417        7417         NaN        x11/yakuake
# 28562     7417        7417         NaN        x11/yakuake
# 28563     7417        7417         NaN        x11/yakuake
#
#                          target_name source_version  target_version   kind
# 61               devel/automake/1.11            NaN             NaN  BUILD
# 62               devel/autoconf/2.69            NaN             NaN  BUILD
# 70          ${_MODLUA_BUILD_DEPENDS}            NaN             NaN  BUILD
# 71                      lang/lua/5.1            NaN             NaN  BUILD
# 72                      lang/lua/5.1            NaN             NaN    RUN
# ...                              ...            ...             ...    ...
# 28554                x11/qt5/qttools            NaN             NaN  BUILD
# 28555            devel/kf5/kdoctools            NaN             NaN  BUILD
# 28558  devel/kf5/extra-cmake-modules            NaN             NaN  BUILD
# 28562   x11/kde-applications/konsole            NaN             NaN    RUN
# 28563            devel/kf5/kdoctools            NaN             NaN    RUN
#
# [5994 rows x 8 columns]

# %%
difference(_df(conan_dep),_df(conan_pkg)).tail(10)
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, target_version_idx]
# Index: []

# %%
difference(_df(alire_dep),_df(alire_pkg))
# gnat package maybe: https://packages.debian.org/sid/gnat
# unixODBC http://www.unixodbc.org/
# Out:
#      pkg_idx  source_idx  target_idx        source_name      target_name  \
# 13       194          22         NaN          openglada             gnat
# 28       267          42         NaN                vss             gnat
# 29       267          45         NaN                vss             gnat
# 188      171         158         NaN   matreshka_league             gnat
# 190      171         159         NaN   matreshka_league             gnat
# 224      273         184         NaN                xia             gnat
# 226      277         188         NaN             yeison             gnat
# 245      223         199         NaN             sdlada             gnat
# 275      212         211         NaN                qoi             gnat
# 301      131         247         NaN             libgpr             gnat
# 303      131         248         NaN             libgpr             gnat
# 358      265         323         NaN          uxstrings             gnat
# 359      265         324         NaN          uxstrings             gnat
# 360      265         325         NaN          uxstrings             gnat
# 362      275         331         NaN             xmlada             gnat
# 383      246         347         NaN        startup_gen             gnat
# 387       22         355         NaN               asis             gnat
# 389       22         356         NaN               asis             gnat
# 391       22         357         NaN               asis             gnat
# 396      235         366         NaN  simple_components             gnat
# 398      235         366         NaN  simple_components         unixODBC
# 464      241         424         NaN               spat  case(toolchain)
# 466      241         425         NaN               spat  case(toolchain)
# 468      241         426         NaN               spat  case(toolchain)
# 469      240         429         NaN          sparknacl             gnat
# 470      240         430         NaN          sparknacl             gnat
# 471      240         431         NaN          sparknacl             gnat
# 472      239         435         NaN      spark_unbound             gnat
# 509       36         453         NaN            bbqueue             gnat
# 511       36         454         NaN            bbqueue             gnat
# 513       36         455         NaN            bbqueue             gnat
# 526      233         462         NaN       shoot_n_loot             gnat
# 529       28         463         NaN                aws             gnat
# 532      221         467         NaN            saatana             gnat
# 547       92         483         NaN          iterators             gnat
#
#            source_version                            target_version   kind  \
# 13                  0.6.0                                        <8  BUILD
# 28        22.0.0-20210830                    >=2020|(>=11 & <=2000)  BUILD
# 29                 22.0.0                    >=2020|(>=11 & <=2000)  BUILD
# 188                21.0.0                                     <2000  BUILD
# 190                20.1.0                      <11|(>=2000 & <2021)  BUILD
# 224                 1.4.0                                   >11.0.0  BUILD
# 226                 0.1.0                            >=11.2 & <2000  BUILD
# 245                 2.3.1                          =2019 | <=11.0.0  BUILD
# 275                 0.1.0                                    >=11.2  BUILD
# 301                21.0.0                                    /=2021  BUILD
# 303                22.0.0                                    /=2020  BUILD
# 358  0.2.0+alpha-20210405                                    >=2020  BUILD
# 359  0.1.2+alpha-20210226                                    >=2020  BUILD
# 360  0.3.0+alpha-20220226                                    >=2021  BUILD
# 362                22.0.0                                      >=11  BUILD
# 383                21.0.0                                      >=10  BUILD
# 387              2019.0.0                                     =2019  BUILD
# 389              2018.0.0                                     =2018  BUILD
# 391              2017.0.0                                     =2017  BUILD
# 396                4.42.0                              /=2021 & <11  BUILD
# 398                4.42.0                                      ^2.3  BUILD
# 464                 1.0.0  {'system': {'gnatcoll': '>=19 & <2000'}}  BUILD
# 466                 1.3.0          {'system': {'gnatcoll': '>=19'}}  BUILD
# 468                 1.2.1  {'system': {'gnatcoll': '>=19 & <2000'}}  BUILD
# 469                 2.0.0                                    >=2020  BUILD
# 470                 3.0.0                                  >=11.2.1  BUILD
# 471                 1.0.0                                    >=2020  BUILD
# 472                 0.2.1                (>=9.3.1 & <2000) | >=2021  BUILD
# 509                 0.1.0                                      >=10  BUILD
# 511                 0.3.0                                      >=10  BUILD
# 513                 0.2.0                                      >=10  BUILD
# 526                 1.0.0                                       ^10  BUILD
# 529                21.0.0                                       >=9  BUILD
# 532                 2.0.2                                     ^2020  BUILD
# 547                 0.1.0                                      >=10  BUILD
#
#     os_platform
# 13          NaN
# 28          NaN
# 29          NaN
# 188       macos
# 190         ...
# 224         NaN
# 226         NaN
# 245         NaN
# 275         NaN
# 301         NaN
# 303         NaN
# 358         NaN
# 359         NaN
# 360         NaN
# 362         NaN
# 383         NaN
# 387         NaN
# 389         NaN
# 391         NaN
# 396         NaN
# 398         NaN
# 464         NaN
# 466         NaN
# 468         NaN
# 469         NaN
# 470         NaN
# 471         NaN
# 472         NaN
# 509         NaN
# 511         NaN
# 513         NaN
# 526         NaN
# 529         NaN
# 532         NaN
# 547         NaN

# %%
difference(_df(cargo_dep),_df(cargo_pkg)).tail(10)
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, optional, target]
# Index: []

# %%
difference(_df(nimble_dep),_df(nimble_pkg))
# here nim is the language itself? https://nim-lang.org/install.html
# Out:
#       pkg_idx  source_idx  target_idx source_name target_name source_version  \
# 0         NaN           0         NaN     libtcod         nim        1.112.0
# 2       666.0           1         NaN      netpbm         nim          0.1.0
# 3         NaN           2         NaN     xgboost         nim          0.1.3
# 4      1447.0           3         NaN   parasound         nim          1.0.0
# 5       954.0           4         NaN   nimassets         nim          0.2.3
# ...       ...         ...         ...         ...         ...            ...
# 3214    574.0        1906         NaN        jack         nim          0.1.0
# 3215   1530.0        1907         NaN     timelog         nim          1.3.0
# 3217   1006.0        1909         NaN    parseini         nim          0.2.0
# 3218   1476.0        1910         NaN     packets         nim          0.4.1
# 3221   1185.0        1911         NaN   asciitype         nim          0.1.0
#
#      target_version   kind
# 0         >= 0.18.1  BUILD
# 2         >= 0.17.2  BUILD
# 3          >= 1.4.0  BUILD
# 4          >= 1.2.6  BUILD
# 5          >= 1.4.0  BUILD
# ...             ...    ...
# 3214      >= 0.16.0  BUILD
# 3215       >= 1.4.0  BUILD
# 3217      >= 0.19.0  BUILD
# 3218      >= 1.4.00  BUILD
# 3221       >= 1.0.2  BUILD
#
# [1876 rows x 8 columns]

# %%
difference(_df(vcpkg_dep),_df(vcpkg_pkg)).tail(10)
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, os_platform]
# Index: []

# %%
difference(_df(fpm_dep),_df(fpm_pkg))
# Out:
#     pkg_idx  source_idx  target_idx source_name    target_name source_version  \
# 2         2           3         NaN      jsonff         erloff          3.0.0
# 4         2           3         NaN      jsonff          parff          3.0.0
# 9        12          13         NaN       quaff         erloff          0.4.0
# 11       12          13         NaN       quaff          parff          0.4.0
# 13       12          13         NaN       quaff  quaff_asserts          0.4.0
#
#    target_version   kind
# 2          v2.1.0  BUILD
# 4          v3.1.4  BUILD
# 9          v2.1.0  BUILD
# 11         v3.1.0  BUILD
# 13            NaN    DEV

# %%
difference(_df(freebsd11_dep),_df(freebsd11_pkg)).tail(10)
# Out:
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind]
# Index: []
