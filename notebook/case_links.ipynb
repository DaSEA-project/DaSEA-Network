# %%
import pandas as pd
data_path = '../data'
alire_pkg = '/alire/alire_packages_04-22-2022.csv'
alire_dep = '/alire/alire_dependencies_04-22-2022.csv'
cargo_pkg = '/cargo/cargo_packages_04-22-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_04-22-2022.csv'
chromebrew_pkg = '/chromebrew/chromebrew_packages_04-22-2022.csv'
chromebrew_dep = '/chromebrew/chromebrew_dependencies_04-22-2022.csv'
clojars_pkg = '/clojars/clojars_packages_03-27-2022.csv'
clojars_dep = '/clojars/clojars_dependencies_03-27-2022.csv'
conan_pkg = '/conan/conan_packages_04-22-2022.csv'
conan_dep = '/conan/conan_dependencies_04-22-2022.csv'
freebsd11_pkg = '/ports/freebsd11/freebsd11_packages_03-218-2022.csv'
freebsd11_dep = '/ports/freebsd11/freebsd11_dependencies_03-18-2022.csv'
fpm_pkg = '/fpm/fpm_packages_03-27-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_03-27-2022.csv'
homebrew_pkg = '/homebrew/homebrew_packages_03-27-2022.csv'
homebrew_dep = '/homebrew/homebrew_dependencies_03-27-2022.csv'
netbsd9_pkg = '/ports/netbsd9/netbsd9_packages_03-27-2022.csv'
netbsd9_dep = '/ports/netbsd9/netbsd9_dependencies_03-27-2022.csv'
nimble_pkg = '/nimble/nimble_packages_03-27-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_03-27-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_03-18-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_03-18-2022.csv'
rubygems_pkg = '/rubygems/rubygems_packages_03-27-2022.csv'
rubygems_dep = '/rubygems/rubygems_dependencies_03-27-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_04-22-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_04-22-2022.csv'
lua_pkg = '/luarocks/luarocks_packages_03-22-2022.csv'
lua_dep = '/luarocks/luarocks_dependencies_03-22-2022.csv'

# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    return pd.read_csv(data_path + path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['name'].isin(x.symmetric_difference(y))]

## Use if you want to find packages that match in ecosystems by name 
def intersect(df_x, df_y):
    x = set(df_x.name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['name'].isin(x.intersection(y))]

def check_transitvity(df_a, df_b, df_c):
    # Transitive dependency when A --> B --> C (A has dependency to C)
    not_ac_df = difference(df_a, df_c)
    return not_ac_df
    
# check_transitvity(_df(vcpkg_pkg), _)

# %%
intersect(_df(vcpkg_pkg), _df_ports(netbsd9_pkg))
# Out:
#        idx       name pkgman
# 2        2     abseil  VCPKG
# 10      10       alac  VCPKG
# 14      14   allegro5  VCPKG
# 27      27        apr  VCPKG
# 28      28   apr-util  VCPKG
# ...    ...        ...    ...
# 1898  1898       zlib  VCPKG
# 1900  1900  zookeeper  VCPKG
# 1901  1901     zopfli  VCPKG
# 1904  1904       zstd  VCPKG
# 1909  1909    zziplib  VCPKG
#
# [371 rows x 3 columns]

# %%
import pandas as pd

data_path = '../data'

alire_pkg = '/alire/alire_packages_04-22-2022.csv'
alire_dep = '/alire/alire_dependencies_04-22-2022.csv'
cargo_pkg = '/cargo/cargo_packages_04-22-2022.csv'
cargo_dep = '/cargo/cargo_dependencies_04-22-2022.csv'
chromebrew_pkg = '/chromebrew/chromebrew_packages_04-22-2022.csv'
chromebrew_dep = '/chromebrew/chromebrew_dependencies_04-22-2022.csv'
clojars_pkg = '/clojars/clojars_packages_03-27-2022.csv'
clojars_dep = '/clojars/clojars_dependencies_03-27-2022.csv'
conan_pkg = '/conan/conan_packages_04-22-2022.csv'
conan_dep = '/conan/conan_dependencies_04-22-2022.csv'
freebsd11_pkg = '/ports/freebsd11/freebsd11_packages_03-218-2022.csv'
freebsd11_dep = '/ports/freebsd11/freebsd11_dependencies_03-18-2022.csv'
fpm_pkg = '/fpm/fpm_packages_03-27-2022.csv'
fpm_dep = '/fpm/fpm_dependencies_03-27-2022.csv'
homebrew_pkg = '/homebrew/homebrew_packages_03-27-2022.csv'
homebrew_dep = '/homebrew/homebrew_dependencies_03-27-2022.csv'
netbsd9_pkg = '/ports/netbsd9/netbsd9_packages_03-27-2022.csv'
netbsd9_dep = '/ports/netbsd9/netbsd9_dependencies_03-27-2022.csv'
nimble_pkg = '/nimble/nimble_packages_03-27-2022.csv'
nimble_dep = '/nimble/nimble_dependencies_03-27-2022.csv'
openbsd69_pkg = '/ports/openbsd69/openbsd69_packages_03-18-2022.csv'
openbsd69_dep = '/ports/openbsd69/openbsd69_dependencies_03-18-2022.csv'
rubygems_pkg = '/rubygems/rubygems_packages_03-27-2022.csv'
rubygems_dep = '/rubygems/rubygems_dependencies_03-27-2022.csv'
vcpkg_pkg = '/vcpkg/vcpkg_packages_04-22-2022.csv'
vcpkg_dep = '/vcpkg/vcpkg_dependencies_04-22-2022.csv'
lua_pkg = '/luarocks/luarocks_packages_03-22-2022.csv'
lua_dep = '/luarocks/luarocks_dependencies_03-22-2022.csv'



# Remove Freebsd11 prefix
def split_prefix(x):
	return x.split('/')[1]

def _df(path):
    file_path = os.path.abspath(data_path + path)
    return pd.read_csv(file_path)

def _df_ports(path):
    df = _df(path)
    df['name'] = df['name'].apply(split_prefix)
    return df

## Use this to find packages that point to non-existing package dependency
def difference(df_x, df_y):
    x = set(df_x.target_name.tolist())
    y = set(df_y.name.tolist())
    return df_x.loc[df_x['target_name'].isin(x.symmetric_difference(y))]

#_df(openbsd69_pkg)
#'gnatt' in _df(vcpkg_pkg)

# %%
print("OPENBSD")
print("HAS SOME FINDINGS")

# difference(_df(openbsd69_dep),_df(openbsd69_pkg))

# lang/lua/5.1 References to the lua language? -> Yes, with a specific version. it is required by this package: archivers/luazlib	(lua-zlib Simple streaming interface to zlib for the Lua Programming Language)
# x11/qt5/qttools	 https://github.com/qt/qttools  https://code.qt.io/cgit/qt/qttools.git/tree/

# devel/kf5/kdoctools https://ftp.netbsd.org/pub/pkgsrc/current/pkgsrc/devel/kdoctools/index.html NetBSD
# devel/kf5/extra-cmake-modules	https://www.freshports.org/devel/kf5-extra-cmake-modules #The Extra CMake Modules package, or ECM, adds to the modules provided by CMake,
# devel/kf5 -> kf5-kitemmodels KF5 models for Qt Model/View system

### Process:
# 1. Manually try to find the target package (target_name) or something similar to get an idea what the package is for
# 2. Find the package that has the dependency (source_name) and use description to verify hypothesis

# TODO: Discuss with the team if we can use the description to find the package
# Out:
# OPENBSD
# HAS SOME FINDINGS

# %%
print("NETBSD")
print("NO FINDINGS")

difference(_df(netbsd9_dep),_df(netbsd9_pkg))
# Out:
# NETBSD
# NO FINDINGS
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind]
# Index: []

# %%
print("FREEBSD")
print("NO FINDINGS")
difference(_df(freebsd11_dep),_df(freebsd11_pkg))
# Out:
# FREEBSD
# NO FINDINGS

# %%
print("CONAN")
print("NO FINDINGS")
difference(_df(conan_dep),_df(conan_pkg))
# Out:
# CONAN
# NO FINDINGS
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, revision]
# Index: []

# %%
print("ALIRE")
print("HAS SOME FINDINGS")

difference(_df(alire_dep),_df(alire_pkg))

# gnat package maybe: https://packages.debian.org/sid/gnat
# unixODBC http://www.unixodbc.org/

# I think the spat case(toolchain) dependencies are old, now i find only -> https://alire.ada.dev/crates/spat
# Out:
# ALIRE
# HAS SOME FINDINGS
#      pkg_idx  source_idx  target_idx        source_name      target_name  \
# 13       201          22         NaN          openglada             gnat
# 30       278          44         NaN                vss             gnat
# 31       278          47         NaN                vss             gnat
# 194      178         162         NaN   matreshka_league             gnat
# 196      178         163         NaN   matreshka_league             gnat
# 230      284         191         NaN                xia             gnat
# 233      288         196         NaN             yeison             gnat
# 252      232         207         NaN             sdlada             gnat
# 286      220         220         NaN                qoi             gnat
# 312      138         256         NaN             libgpr             gnat
# 314      138         257         NaN             libgpr             gnat
# 369      276         337         NaN          uxstrings             gnat
# 370      276         338         NaN          uxstrings             gnat
# 371      276         339         NaN          uxstrings             gnat
# 374      286         346         NaN             xmlada             gnat
# 396      257         363         NaN        startup_gen             gnat
# 400       22         372         NaN               asis             gnat
# 402       22         373         NaN               asis             gnat
# 404       22         374         NaN               asis             gnat
# 409      246         383         NaN  simple_components             gnat
# 411      246         383         NaN  simple_components         unixODBC
# 481      252         444         NaN               spat  case(toolchain)
# 483      252         445         NaN               spat  case(toolchain)
# 485      252         446         NaN               spat  case(toolchain)
# 486      251         449         NaN          sparknacl             gnat
# 487      251         450         NaN          sparknacl             gnat
# 488      251         451         NaN          sparknacl             gnat
# 489      250         455         NaN      spark_unbound             gnat
# 530       36         474         NaN            bbqueue             gnat
# 532       36         475         NaN            bbqueue             gnat
# 534       36         476         NaN            bbqueue             gnat
# 553      244         487         NaN       shoot_n_loot             gnat
# 556       28         491         NaN                aws             gnat
# 559      230         495         NaN            saatana             gnat
# 574       99         511         NaN          iterators             gnat
#
#            source_version                            target_version   kind  \
# 13                  0.6.0                                        <8  BUILD
# 30        22.0.0-20210830                    >=2020|(>=11 & <=2000)  BUILD
# 31                 22.0.0                    >=2020|(>=11 & <=2000)  BUILD
# 194                21.0.0                                     <2000  BUILD
# 196                20.1.0                      <11|(>=2000 & <2021)  BUILD
# 230                 1.4.0                                   >11.0.0  BUILD
# 233                 0.1.0                            >=11.2 & <2000  BUILD
# 252                 2.3.1                          =2019 | <=11.0.0  BUILD
# 286                 0.1.0                                    >=11.2  BUILD
# 312                21.0.0                                    /=2021  BUILD
# 314                22.0.0                                    /=2020  BUILD
# 369  0.2.0+alpha-20210405                                    >=2020  BUILD
# 370  0.1.2+alpha-20210226                                    >=2020  BUILD
# 371  0.3.0+alpha-20220226                                    >=2021  BUILD
# 374                22.0.0                                      >=11  BUILD
# 396                21.0.0                                      >=10  BUILD
# 400              2019.0.0                                     =2019  BUILD
# 402              2018.0.0                                     =2018  BUILD
# 404              2017.0.0                                     =2017  BUILD
# 409                4.42.0                              /=2021 & <11  BUILD
# 411                4.42.0                                      ^2.3  BUILD
# 481                 1.0.0  {'system': {'gnatcoll': '>=19 & <2000'}}  BUILD
# 483                 1.3.0          {'system': {'gnatcoll': '>=19'}}  BUILD
# 485                 1.2.1  {'system': {'gnatcoll': '>=19 & <2000'}}  BUILD
# 486                 2.0.0                                    >=2020  BUILD
# 487                 3.0.0                                  >=11.2.1  BUILD
# 488                 1.0.0                                    >=2020  BUILD
# 489                 0.2.1                (>=9.3.1 & <2000) | >=2021  BUILD
# 530                 0.1.0                                      >=10  BUILD
# 532                 0.3.0                                      >=10  BUILD
# 534                 0.2.0                                      >=10  BUILD
# 553                 1.0.0                                       ^10  BUILD
# 556                21.0.0                                       >=9  BUILD
# 559                 2.0.2                                     ^2020  BUILD
# 574                 0.1.0                                      >=10  BUILD
#
#     os_platform
# 13          NaN
# 30          NaN
# 31          NaN
# 194       macos
# 196         ...
# 230         NaN
# 233         NaN
# 252         NaN
# 286         NaN
# 312         NaN
# 314         NaN
# 369         NaN
# 370         NaN
# 371         NaN
# 374         NaN
# 396         NaN
# 400         NaN
# 402         NaN
# 404         NaN
# 409         NaN
# 411         NaN
# 481         NaN
# 483         NaN
# 485         NaN
# 486         NaN
# 487         NaN
# 488         NaN
# 489         NaN
# 530         NaN
# 532         NaN
# 534         NaN
# 553         NaN
# 556         NaN
# 559         NaN
# 574         NaN

# %%
print("CARGO")
print("NO FINDINGS")
difference(_df(cargo_dep),_df(cargo_pkg))
# Out:
# CARGO
# NO FINDINGS
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, optional, target]
# Index: []

# %%
print("NIMBLE")
print("HAS SOME FINDINGS")
difference(_df(nimble_dep),_df(nimble_pkg))

# here nim is the language itself? https://nim-lang.org/install.html
# TODO: An idea is compare if the package is for the language itself by using the pkgman field in the packages.csv file. Discuss with team
# Out:
# NIMBLE
# HAS SOME FINDINGS
#       pkg_idx  source_idx  target_idx source_name target_name source_version  \
# 0         NaN           0         NaN     libtcod         nim        1.112.0
# 2       667.0           1         NaN      netpbm         nim          0.1.0
# 3         NaN           2         NaN     xgboost         nim          0.1.3
# 4      1448.0           3         NaN   parasound         nim          1.0.0
# 5       955.0           4         NaN   nimassets         nim          0.2.3
# ...       ...         ...         ...         ...         ...            ...
# 3236    575.0        1913         NaN        jack         nim          0.1.0
# 3237   1531.0        1914         NaN     timelog         nim          1.3.0
# 3239   1007.0        1916         NaN    parseini         nim          0.2.0
# 3240   1477.0        1917         NaN     packets         nim          0.4.1
# 3243   1186.0        1918         NaN   asciitype         nim          0.1.0
#
#      target_version   kind
# 0         >= 0.18.1  BUILD
# 2         >= 0.17.2  BUILD
# 3          >= 1.4.0  BUILD
# 4          >= 1.2.6  BUILD
# 5          >= 1.4.0  BUILD
# ...             ...    ...
# 3236      >= 0.16.0  BUILD
# 3237       >= 1.4.0  BUILD
# 3239      >= 0.19.0  BUILD
# 3240      >= 1.4.00  BUILD
# 3243       >= 1.0.2  BUILD
#
# [1887 rows x 8 columns]

# %%
print("VCPG")
print("NO FINDINGS")
difference(_df(vcpkg_dep),_df(vcpkg_pkg)).tail(10)
# Out:
# VCPG
# NO FINDINGS
# Empty DataFrame
# Columns: [pkg_idx, source_idx, target_idx, source_name, target_name, source_version, target_version, kind, os_platform]
# Index: []

# %%
print("FPM")
print("HAS SOME FINDINGS")
difference(_df(fpm_dep),_df(fpm_pkg))

# erloff maybe this: https://gitlab.com/everythingfunctional/erloff, but removed from official docs: https://everythingfunctional.gitlab.io/erloff/
# quaff_asserts couldn't find anything

# Process: Manual lookup for every package. Likely package was deleted.
# Out:
# FPM
# HAS SOME FINDINGS
#     pkg_idx  source_idx  target_idx source_name    target_name source_version  \
# 2         2           3         NaN      jsonff         erloff          3.0.0
# 4         2           3         NaN      jsonff          parff          3.0.0
# 9        12          13         NaN       quaff         erloff          0.4.0
# 11       12          13         NaN       quaff          parff          0.4.0
# 13       12          13         NaN       quaff  quaff_asserts          0.4.0
#
#    target_version   kind
# 2          v2.1.0  BUILD
# 4          v3.1.4  BUILD
# 9          v2.1.0  BUILD
# 11         v3.1.0  BUILD
# 13            NaN    DEV

# %%
print("CHROMEBREW")
print("HAS SOME FINDINGS")
difference(_df(chromebrew_dep),_df(chromebrew_pkg))

# libjpeg_turbo https://libjpeg-turbo.org/ https://github.com/libjpeg-turbo/libjpeg-turbo
# gfortran https://linux.die.net/man/1/gfortran Fortran compiler

## TODO: Cross Chromebrew with FPM

## GenuineIntel: CPU?

## TODO: Are these numbers x86_64 errors?

## gyp related to https://github.com/nodejs/gyp-next? -> https://pypi.org/project/gyp/ ?? TODO: check with Pypi
# Out:
# CHROMEBREW
# HAS SOME FINDINGS
#       pkg_idx  source_idx  target_idx        source_name    target_name  \
# 30         16           0         NaN              hplip  libjpeg_turbo
# 448       177           0         NaN                  r       gfortran
# 523       199           0         NaN             ffmpeg         x86_64
# 524       199           0         NaN             ffmpeg   GenuineIntel
# 536       199           0         NaN             ffmpeg           i686
# 537       199           0         NaN             ffmpeg   GenuineIntel
# 864       309           0         NaN     buildessential            gyp
# 1146      423           0         NaN           testdisk  libjpeg_turbo
# 1524      533           0         NaN               bash           i686
# 1690      596           0         NaN  template.template              *
# 2097      756           0         NaN     musl_toolchain           i686
# 2099      756           0         NaN     musl_toolchain           i686
# 2506      919           0         NaN               gtk4         x86_64
# 2534      919           0         NaN               gtk4           i686
# 2536      919           0         NaN               gtk4         x86_64
# 2571      925           0         NaN             libefl  libjpeg_turbo
# 3007     1090           0         NaN            libavif         x86_64
# 3406     1252           0         NaN            glmark2  libjpeg_turbo
# 3631     1329           0         NaN         util_linux         x86_64
# 4163     1534           0         NaN          wireshark           i686
# 4165     1534           0         NaN          wireshark           i686
# 4167     1534           0         NaN          wireshark           i686
#
#       source_version target_version   kind
# 30               5.7            NaN  BUILD
# 448              5.7            NaN  BUILD
# 523              5.7            NaN  BUILD
# 524              5.7            NaN  BUILD
# 536              5.7            NaN  BUILD
# 537              5.7            NaN  BUILD
# 864              5.7            NaN  BUILD
# 1146             5.7            NaN  BUILD
# 1524             5.7            NaN  BUILD
# 1690             5.7            NaN  BUILD
# 2097             5.7            NaN  BUILD
# 2099             5.7            NaN  BUILD
# 2506             5.7            NaN  BUILD
# 2534             5.7            NaN  BUILD
# 2536             5.7            NaN  BUILD
# 2571             5.7            NaN  BUILD
# 3007             5.7            NaN  BUILD
# 3406             5.7            NaN  BUILD
# 3631             5.7            NaN  BUILD
# 4163             5.7            NaN  BUILD
# 4165             5.7            NaN  BUILD
# 4167             5.7            NaN  BUILD

# %%
print("CLOJARS")
print("NEED TO FIX CLOJARS MINER, ISSUE WITH DEPS FILE")
#difference(_df(clojars_dep),_df(clojars_pkg))
# Out:
# CLOJARS
# NEED TO FIX CLOJARS MINER, ISSUE WITH DEPS FILE

# %%
print("HOMEBREW")
print("HAS SOME FINDINGS")
difference(_df(homebrew_dep),_df(homebrew_pkg))

# Directly points to python language
# TODO: Another case with directly pointing to language

# TODO: Also the source_name package is node@16 and node, so it seems like they bundle Node as a package?
# Out:
# HOMEBREW
# HAS SOME FINDINGS
#        pkg_idx  source_idx  target_idx   source_name target_name  \
# 1691       741         741         NaN  clang-format      python
# 6469      2529        2529         NaN         julia      python
# 10124     3781        3781         NaN          node      python
# 10160     3787        3787         NaN       node@16      python
#
#       source_version  target_version             kind
# 1691          13.0.1             NaN  USES_FROM_MACOS
# 6469           1.7.2             NaN            build
# 10124         17.8.0             NaN  USES_FROM_MACOS
# 10160        16.14.2             NaN  USES_FROM_MACOS

# %%
print("RUBYGEMS")
print("NEED TO FIX RUBYGEMS MINER, ISSUE WITH DEPS FILE")
# difference(_df(rubygems_dep),_df(rubygems_pkg))
# Out:
# RUBYGEMS
# NEED TO FIX RUBYGEMS MINER, ISSUE WITH DEPS FILE
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_79130/1682494375.py in <module>
#       1 print("RUBYGEMS")
#       2 print("NEED TO FIX RUBYGEMS MINER, ISSUE WITH DEPS FILE")
# ----> 3 difference(_df(rubygems_dep),_df(rubygems_pkg))
#
# /tmp/ipykernel_79130/646114007.py in difference(df_x, df_y)
#      49 ## Use this to find packages that point to non-existing package dependency
#      50 def difference(df_x, df_y):
# ---> 51     x = set(df_x.target_name.tolist())
#      52     y = set(df_y.name.tolist())
#      53     return df_x.loc[df_x['target_name'].isin(x.symmetric_difference(y))]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target_name'

# %%
# Namings for packages: crates (Alire), packages (Ports),
